# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os
sys.path.append('../')

# Graph imports
import src.graph as graph
import src.logit_estimator as estimator
import src.utils as utils
import src.model_selection as model_selection
import src.gic as gic
import src.param_estimator as pe
import src.graph as graph

# usual imports
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import gc
import random
import networkx as nx

from IPython.display import display
from pyvis.network import Network

import pickle
import os

np.random.seed(42)

# %%
final_df = pd.read_csv('estimation_results_connectomes.csv')

# %%
final_df.head()
# Out:
#                               Unnamed: 0         AIC         BIC     sigma  \
# 0  p.pacificus_neural.synaptic_2.graphml    694.6735    710.0056 -3.823346
# 1       rhesus_cerebral.cortex_1.graphml   3726.1077   3745.0602 -3.968125
# 2      rattus.norvegicus_brain_1.graphml  33848.4629  33877.7010 -6.583911
# 3          mixed.species_brain_1.graphml   2209.2066   2226.1270 -4.622072
# 4          mouse_visual.cortex_2.graphml   1511.9046   1535.4477 -6.392157
#
#    Std Error of sigma  0.025 CI of sigma  0.975 CI of sigma  Depth (d)  \
# 0            0.203345          -4.221894          -3.424798          1
# 1            0.121986          -4.207213          -3.729037          1
# 2            0.039424          -6.661181          -6.506641          1
# 3            0.223560          -5.060242          -4.183902          1
# 4            0.162297          -6.710253          -6.074061          1
#
#    species
# 0     worm
# 1  macaque
# 2      rat
# 3      cat
# 4    mouse
